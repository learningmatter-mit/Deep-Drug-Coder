# %%
# %load_ext autoreload
# %autoreload 2
# Occupy a GPU for the model to be loaded 
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# GPU ID, if occupied change to an available GPU ID listed under !nvidia-smi
# %env CUDA_VISIBLE_DEVICES=2

import numpy as np
from rdkit import Chem, DataStructs
import h5py, ast, pickle
import pandas as pd

from ddc_pub import ddc_v3 as ddc
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=2

# %%
data = pd.read_csv('./datasets/OPD_Data/FP_TL_Training_Validation.csv')['smiles'].tolist()

# %%
binmols = [(Chem.MolFromSmiles(smiles)) for smiles in data]
mols_in = [Chem.rdchem.Mol.ToBinary(smiles) for smiles in binmols]

# %%
# All apriori known characters of the SMILES in the dataset
charset = 'a0bMAuGpgFL=(-2l+i)5mYtVnD\\%TPI8y1S3N7OZ/#CsRUfd@Be9Eo[WKcrH4]6h^$?'
# Apriori known max length of the SMILES in the dataset
maxlen = 445
# Name of the dataset
name = "opd_fp_complete"

dataset_info = {"charset": charset, "maxlen": maxlen, "name": name}

# %%
# Initialize a model
model = ddc.DDC(x              = mols_in,      # input
                y              = mols_in,      # output
                dataset_info = dataset_info,
                name = './models/opd_fp_complete'
               )
# Out:
# Initializing model in train mode.
# Input type is 'binary mols'.
# Model received 12254 train samples and 1362 validation samples.
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Encoder_Inputs (InputLayer)     [(None, 460, 67)]    0
# __________________________________________________________________________________________________
# mol_to_latent_model (Model)     (None, 128)          733824      Encoder_Inputs[0][0]
# __________________________________________________________________________________________________
# Decoder_Inputs (InputLayer)     [(None, 459, 67)]    0
# __________________________________________________________________________________________________
# latent_to_states_model (Model)  [(None, 256), (None, 136192      mol_to_latent_model[1][0]
# __________________________________________________________________________________________________
# batch_model (Model)             (None, 459, 67)      878403      Decoder_Inputs[0][0]
#                                                                  latent_to_states_model[1][0]
#                                                                  latent_to_states_model[1][1]
#                                                                  latent_to_states_model[1][2]
#                                                                  latent_to_states_model[1][3]
# ==================================================================================================
# Total params: 1,748,419
# Trainable params: 1,742,531
# Non-trainable params: 5,888
# __________________________________________________________________________________________________
# None

# %%
model.fit(epochs              = 100,         # number of epochs
          lr                  = 1e-3,        # initial learning rate for Adam, recommended
          model_name          = "opd_fp_tl", # base name to append the checkpoints with
          checkpoint_dir      = "./models/", # save checkpoints in the notebook's directory
          mini_epochs         = 10,          # number of sub-epochs within an epoch to trigger lr decay
          save_period         = 50,          # checkpoint frequency (in mini_epochs)
          lr_decay            = True,        # whether to use exponential lr decay or not
          sch_epoch_to_start  = 500,         # mini-epoch to start lr decay (bypassed if lr_decay=False)
          sch_lr_init         = 1e-3,        # initial lr, should be equal to lr (bypassed if lr_decay=False)
          sch_lr_final        = 1e-6,        # final lr before finishing training (bypassed if lr_decay=False)
          patience            = 25)          # patience for Keras' ReduceLROnPlateau (bypassed if lr_decay=True)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
#
# Model trained with dataset 200614_fp--1000--0.0282--0.0000010 that has maxlen=455 and charset=a0bMAuGpgFL=(-2l+i)5mYtVnD\%TPI8y1S3N7OZ/#CsRUfd@Be9Eo[WKcrH4]6h^$? for 100 epochs.
# noise_std: 0.010000, lstm_dim: 256, dec_layers: 2, td_dense_dim: 0, batch_size: 256, codelayer_dim: 128, lr: 0.001000.
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/1000
# 5/4 - 11s - loss: 2.3586 - val_loss: 6.9807
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/1000
# 5/4 - 3s - loss: 0.9473 - val_loss: 7.8362
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/1000
# 5/4 - 3s - loss: 0.6501 - val_loss: 8.8744
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/1000
# 5/4 - 3s - loss: 0.5164 - val_loss: 9.4952
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 5/1000
# 5/4 - 3s - loss: 0.4361 - val_loss: 9.5330
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 6/1000
# 5/4 - 3s - loss: 0.3846 - val_loss: 8.9273
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 7/1000
# 5/4 - 3s - loss: 0.3585 - val_loss: 5.7327
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 8/1000
# 5/4 - 3s - loss: 0.3390 - val_loss: 7.5716
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 9/1000
# 5/4 - 3s - loss: 0.3118 - val_loss: 2.9478
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 10/1000
# 5/4 - 3s - loss: 0.2941 - val_loss: 1.5500
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 11/1000
# 5/4 - 3s - loss: 0.2839 - val_loss: 0.9962
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 12/1000
# 5/4 - 3s - loss: 0.2659 - val_loss: 0.7938
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 13/1000
# 5/4 - 3s - loss: 0.2611 - val_loss: 0.7063
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 14/1000
# 5/4 - 3s - loss: 0.2555 - val_loss: 0.6435
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 15/1000
# 5/4 - 3s - loss: 0.2476 - val_loss: 0.6293
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 16/1000
# 5/4 - 3s - loss: 0.2432 - val_loss: 0.6324
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 17/1000
# 5/4 - 3s - loss: 0.2418 - val_loss: 0.6054
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 18/1000
# 5/4 - 3s - loss: 0.2312 - val_loss: 0.5988
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 19/1000
# 5/4 - 4s - loss: 0.2316 - val_loss: 0.5782
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 20/1000
# 5/4 - 3s - loss: 0.2293 - val_loss: 0.6018
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 21/1000
# 5/4 - 3s - loss: 0.2244 - val_loss: 0.5823
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 22/1000
# 5/4 - 3s - loss: 0.2234 - val_loss: 0.5765
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 23/1000
# 5/4 - 3s - loss: 0.2200 - val_loss: 0.5555
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 24/1000
# 5/4 - 3s - loss: 0.2186 - val_loss: 0.5266
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 25/1000
# 5/4 - 3s - loss: 0.2147 - val_loss: 0.5547
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 26/1000
# 5/4 - 3s - loss: 0.2134 - val_loss: 0.5440
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 27/1000
# 5/4 - 3s - loss: 0.2109 - val_loss: 0.5487
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 28/1000
# 5/4 - 3s - loss: 0.2064 - val_loss: 0.5313
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 29/1000
# 5/4 - 3s - loss: 0.2073 - val_loss: 0.5330
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 30/1000
# 5/4 - 3s - loss: 0.2044 - val_loss: 0.5316
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 31/1000
# 5/4 - 3s - loss: 0.2087 - val_loss: 0.5015
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 32/1000
# 5/4 - 3s - loss: 0.2043 - val_loss: 0.5041
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 33/1000
# 5/4 - 3s - loss: 0.2037 - val_loss: 0.5073
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 34/1000
# 5/4 - 3s - loss: 0.2012 - val_loss: 0.5852
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 35/1000
# 5/4 - 3s - loss: 0.2001 - val_loss: 0.6079
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 36/1000
# 5/4 - 3s - loss: 0.1985 - val_loss: 0.5611
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 37/1000
# 5/4 - 3s - loss: 0.1959 - val_loss: 0.4964
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 38/1000
# 5/4 - 4s - loss: 0.1983 - val_loss: 0.4908
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 39/1000
# 5/4 - 3s - loss: 0.1958 - val_loss: 0.4772
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 40/1000
# 5/4 - 3s - loss: 0.1965 - val_loss: 0.4834
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 41/1000
# 5/4 - 3s - loss: 0.1927 - val_loss: 0.4999
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 42/1000
# 5/4 - 3s - loss: 0.1911 - val_loss: 0.4869
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 43/1000
# 5/4 - 3s - loss: 0.1924 - val_loss: 0.4878
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 44/1000
# 5/4 - 3s - loss: 0.1927 - val_loss: 0.5140
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 45/1000
# 5/4 - 3s - loss: 0.1891 - val_loss: 0.6541
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 46/1000
# 5/4 - 3s - loss: 0.1883 - val_loss: 0.6521
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 47/1000
# 5/4 - 3s - loss: 0.1879 - val_loss: 0.4773
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 48/1000
# 5/4 - 3s - loss: 0.1850 - val_loss: 0.4957
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 49/1000
# 5/4 - 3s - loss: 0.1856 - val_loss: 0.4702
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 50/1000
# Model saved in re_train_fp_--50--0.4706--0.0010000.
# 5/4 - 3s - loss: 0.1855 - val_loss: 0.4706
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 51/1000
# 5/4 - 3s - loss: 0.1848 - val_loss: 0.4582
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 52/1000
# 5/4 - 3s - loss: 0.1825 - val_loss: 0.4801
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 53/1000
# 5/4 - 3s - loss: 0.1841 - val_loss: 0.4949
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 54/1000
# 5/4 - 3s - loss: 0.1815 - val_loss: 0.4551
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 55/1000
# 5/4 - 3s - loss: 0.1822 - val_loss: 0.4689
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 56/1000
# 5/4 - 3s - loss: 0.1792 - val_loss: 0.4925
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 57/1000
# 5/4 - 3s - loss: 0.1829 - val_loss: 0.4700
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 58/1000
# 5/4 - 3s - loss: 0.1767 - val_loss: 0.4890
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 59/1000
# 5/4 - 3s - loss: 0.1797 - val_loss: 0.4704
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 60/1000
# 5/4 - 3s - loss: 0.1777 - val_loss: 0.5122
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 61/1000
# 5/4 - 3s - loss: 0.1794 - val_loss: 0.4621
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 62/1000
# 5/4 - 3s - loss: 0.1766 - val_loss: 0.4964
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 63/1000
# 5/4 - 3s - loss: 0.1761 - val_loss: 0.5062
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 64/1000
# 5/4 - 3s - loss: 0.1744 - val_loss: 0.4974
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 65/1000
# 5/4 - 3s - loss: 0.1744 - val_loss: 0.4810
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 66/1000
# 5/4 - 3s - loss: 0.1726 - val_loss: 0.4657
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 67/1000
# 5/4 - 3s - loss: 0.1738 - val_loss: 0.5622
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 68/1000
# 5/4 - 3s - loss: 0.1717 - val_loss: 0.4554
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 69/1000
# 5/4 - 3s - loss: 0.1744 - val_loss: 0.5177
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 70/1000
# 5/4 - 3s - loss: 0.1715 - val_loss: 0.5331
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 71/1000
# 5/4 - 3s - loss: 0.1674 - val_loss: 0.6131
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 72/1000
# 5/4 - 3s - loss: 0.1751 - val_loss: 0.5928
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 73/1000
# 5/4 - 3s - loss: 0.1694 - val_loss: 0.4644
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 74/1000
# 5/4 - 3s - loss: 0.1722 - val_loss: 0.4601
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 75/1000
# 5/4 - 3s - loss: 0.1729 - val_loss: 7.7432
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 76/1000
# 5/4 - 3s - loss: 0.1712 - val_loss: 0.5051
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 77/1000
# 5/4 - 3s - loss: 0.1698 - val_loss: 0.4691
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 78/1000
# 5/4 - 3s - loss: 0.1675 - val_loss: 0.4733
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 79/1000
# 5/4 - 3s - loss: 0.1664 - val_loss: 0.4466
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 80/1000
# 5/4 - 3s - loss: 0.1612 - val_loss: 0.4164
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 81/1000
# 5/4 - 3s - loss: 0.1704 - val_loss: 0.4772
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 82/1000
# 5/4 - 3s - loss: 0.1650 - val_loss: 0.5269
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 83/1000
# 5/4 - 3s - loss: 0.1680 - val_loss: 0.4824
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 84/1000
# 5/4 - 3s - loss: 0.1668 - val_loss: 0.4262
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 85/1000
# 5/4 - 3s - loss: 0.1640 - val_loss: 0.4436
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 86/1000
# 5/4 - 3s - loss: 0.1656 - val_loss: 0.4550
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 87/1000
# 5/4 - 3s - loss: 0.1610 - val_loss: 0.4782
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 88/1000
# 5/4 - 3s - loss: 0.1597 - val_loss: 0.4554
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 89/1000
# 5/4 - 3s - loss: 0.1619 - val_loss: 0.4753
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 90/1000
# 5/4 - 3s - loss: 0.1617 - val_loss: 0.4418
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 91/1000
# 5/4 - 3s - loss: 0.1652 - val_loss: 12.8649
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 92/1000
# 5/4 - 3s - loss: 0.1621 - val_loss: 0.5207
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 93/1000
# 5/4 - 3s - loss: 0.1598 - val_loss: 2.6439
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 94/1000
# 5/4 - 3s - loss: 0.1621 - val_loss: 0.4949
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 95/1000
# 5/4 - 3s - loss: 0.1585 - val_loss: 0.4347
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 96/1000
# 5/4 - 3s - loss: 0.1575 - val_loss: 0.4127
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 97/1000
# 5/4 - 3s - loss: 0.1568 - val_loss: 0.4435
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 98/1000
# 5/4 - 3s - loss: 0.1561 - val_loss: 0.5518
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 99/1000
# 5/4 - 3s - loss: 0.1573 - val_loss: 1.0224
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 100/1000
# Model saved in re_train_fp_--100--0.6314--0.0010000.
# 5/4 - 3s - loss: 0.1601 - val_loss: 0.6314
#
# Epoch 00101: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 101/1000
# 5/4 - 3s - loss: 0.1561 - val_loss: 0.4583
#
# Epoch 00102: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 102/1000
# 5/4 - 3s - loss: 0.1529 - val_loss: 0.4390
#
# Epoch 00103: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 103/1000
# 5/4 - 3s - loss: 0.1597 - val_loss: 0.5266
#
# Epoch 00104: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 104/1000
# 5/4 - 3s - loss: 0.1572 - val_loss: 0.4570
#
# Epoch 00105: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 105/1000
# 5/4 - 3s - loss: 0.1566 - val_loss: 0.4355
#
# Epoch 00106: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 106/1000
# 5/4 - 3s - loss: 0.1566 - val_loss: 0.4353
#
# Epoch 00107: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 107/1000
# 5/4 - 3s - loss: 0.1532 - val_loss: 0.4314
#
# Epoch 00108: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 108/1000
# 5/4 - 3s - loss: 0.1550 - val_loss: 0.6057
#
# Epoch 00109: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 109/1000
# 5/4 - 3s - loss: 0.1569 - val_loss: 24.9314
#
# Epoch 00110: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 110/1000
# 5/4 - 3s - loss: 0.1565 - val_loss: 23.7450
#
# Epoch 00111: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 111/1000
# 5/4 - 3s - loss: 0.1563 - val_loss: 0.4589
#
# Epoch 00112: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 112/1000
# 5/4 - 3s - loss: 0.1502 - val_loss: 0.6474
# Epoch 00113: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 113/1000
# 5/4 - 3s - loss: 0.1466 - val_loss: 2.6340
#
# Epoch 00114: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 114/1000
# 5/4 - 3s - loss: 0.1450 - val_loss: 24.4966
#
# Epoch 00115: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 115/1000
# 5/4 - 3s - loss: 0.1399 - val_loss: 0.9554
#
# Epoch 00116: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 116/1000
# 5/4 - 3s - loss: 0.1352 - val_loss: 0.6379
#
# Epoch 00117: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 117/1000
# 5/4 - 3s - loss: 0.1347 - val_loss: 0.4178
#
# Epoch 00118: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 118/1000
# 5/4 - 3s - loss: 0.1355 - val_loss: 0.3717
#
# Epoch 00119: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 119/1000
# 5/4 - 3s - loss: 0.1303 - val_loss: 0.3778
#
# Epoch 00120: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 120/1000
# 5/4 - 3s - loss: 0.1300 - val_loss: 0.3620
#
# Epoch 00121: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 121/1000
# 5/4 - 3s - loss: 0.1295 - val_loss: 0.3606
#
# Epoch 00122: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 122/1000
# 5/4 - 3s - loss: 0.1272 - val_loss: 0.3561
#
# Epoch 00123: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 123/1000
# 5/4 - 3s - loss: 0.1255 - val_loss: 0.3464
#
# Epoch 00124: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 124/1000
# 5/4 - 3s - loss: 0.1246 - val_loss: 0.3709
#
# Epoch 00125: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 125/1000
# 5/4 - 3s - loss: 0.1242 - val_loss: 0.4596
#
# Epoch 00126: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 126/1000
# 5/4 - 3s - loss: 0.1268 - val_loss: 0.3975
#
# Epoch 00127: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 127/1000
# 5/4 - 3s - loss: 0.1222 - val_loss: 0.3732
#
# Epoch 00128: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 128/1000
# 5/4 - 3s - loss: 0.1214 - val_loss: 14.1748
#
# Epoch 00129: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 129/1000
# 5/4 - 3s - loss: 0.1239 - val_loss: 0.4671
#
# Epoch 00130: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 130/1000
# 5/4 - 3s - loss: 0.1215 - val_loss: 0.3907
#
# Epoch 00131: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 131/1000
# 5/4 - 3s - loss: 0.1182 - val_loss: 0.3791
#
# Epoch 00132: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 132/1000
# 5/4 - 4s - loss: 0.1208 - val_loss: 12.8863
#
# Epoch 00133: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 133/1000
# 5/4 - 3s - loss: 0.1195 - val_loss: 0.3341
#
# Epoch 00134: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 134/1000
# 5/4 - 3s - loss: 0.1220 - val_loss: 0.3613
#
# Epoch 00135: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 135/1000
# 5/4 - 3s - loss: 0.1175 - val_loss: 0.3260
#
# Epoch 00136: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 136/1000
# 5/4 - 3s - loss: 0.1182 - val_loss: 3.2554
#
# Epoch 00137: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 137/1000
# 5/4 - 3s - loss: 0.1187 - val_loss: 2.2768
#
# Epoch 00138: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 138/1000
# 5/4 - 3s - loss: 0.1194 - val_loss: 0.3500
#
# Epoch 00139: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 139/1000
# 5/4 - 3s - loss: 0.1193 - val_loss: 0.3761
#
# Epoch 00140: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 140/1000
# 5/4 - 3s - loss: 0.1197 - val_loss: 0.3507
#
# Epoch 00141: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 141/1000
# 5/4 - 3s - loss: 0.1168 - val_loss: 0.3784
#
# Epoch 00142: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 142/1000
# 5/4 - 3s - loss: 0.1156 - val_loss: 0.3581
#
# Epoch 00143: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 143/1000
# 5/4 - 3s - loss: 0.1180 - val_loss: 13.9736
#
# Epoch 00144: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 144/1000
# 5/4 - 3s - loss: 0.1199 - val_loss: 0.4884
#
# Epoch 00145: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 145/1000
# 5/4 - 3s - loss: 0.1193 - val_loss: 18.5127
#
# Epoch 00146: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 146/1000
# 5/4 - 3s - loss: 0.1169 - val_loss: 0.3235
#
# Epoch 00147: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 147/1000
# 5/4 - 3s - loss: 0.1155 - val_loss: 0.4574
#
# Epoch 00148: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 148/1000
# 5/4 - 3s - loss: 0.1153 - val_loss: 0.4140
#
# Epoch 00149: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 149/1000
# 5/4 - 3s - loss: 0.1137 - val_loss: 0.8082
#
# Epoch 00150: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 150/1000
# Model saved in re_train_fp_--150--0.4160--0.0010000.
# 5/4 - 3s - loss: 0.1131 - val_loss: 0.4160
#
# Epoch 00151: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 151/1000
# 5/4 - 3s - loss: 0.1153 - val_loss: 0.4860
#
# Epoch 00152: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 152/1000
# 5/4 - 3s - loss: 0.1145 - val_loss: 0.4924
#
# Epoch 00153: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 153/1000
# 5/4 - 3s - loss: 0.1168 - val_loss: 0.3866
#
# Epoch 00154: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 154/1000
# 5/4 - 3s - loss: 0.1155 - val_loss: 0.6291
#
# Epoch 00155: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 155/1000
# 5/4 - 3s - loss: 0.1149 - val_loss: 0.4136
#
# Epoch 00156: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 156/1000
# 5/4 - 3s - loss: 0.1137 - val_loss: 0.3765
#
# Epoch 00157: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 157/1000
# 5/4 - 3s - loss: 0.1117 - val_loss: 0.3541
#
# Epoch 00158: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 158/1000
# 5/4 - 3s - loss: 0.1135 - val_loss: 0.3311
#
# Epoch 00159: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 159/1000
# 5/4 - 3s - loss: 0.1136 - val_loss: 0.4584
#
# Epoch 00160: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 160/1000
# 5/4 - 4s - loss: 0.1099 - val_loss: 0.3565
#
# Epoch 00161: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 161/1000
# 5/4 - 3s - loss: 0.1100 - val_loss: 0.3258
#
# Epoch 00162: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 162/1000
# 5/4 - 3s - loss: 0.1090 - val_loss: 0.3326
#
# Epoch 00163: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 163/1000
# 5/4 - 3s - loss: 0.1112 - val_loss: 0.3185
#
# Epoch 00164: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 164/1000
# 5/4 - 3s - loss: 0.1126 - val_loss: 0.3769
#
# Epoch 00165: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 165/1000
# 5/4 - 3s - loss: 0.1121 - val_loss: 0.3649
#
# Epoch 00166: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 166/1000
# 5/4 - 3s - loss: 0.1104 - val_loss: 0.3492
#
# Epoch 00167: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 167/1000
# 5/4 - 3s - loss: 0.1097 - val_loss: 0.3543
#
# Epoch 00168: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 168/1000
# 5/4 - 3s - loss: 0.1109 - val_loss: 0.3407
#
# Epoch 00169: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 169/1000
# 5/4 - 3s - loss: 0.1088 - val_loss: 0.3341
# Epoch 00170: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 170/1000
# 5/4 - 3s - loss: 0.1073 - val_loss: 0.3035
#
# Epoch 00171: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 171/1000
# 5/4 - 3s - loss: 0.1083 - val_loss: 0.3409
#
# Epoch 00172: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 172/1000
# 5/4 - 3s - loss: 0.1072 - val_loss: 0.3542
#
# Epoch 00173: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 173/1000
# 5/4 - 3s - loss: 0.1095 - val_loss: 0.3501
#
# Epoch 00174: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 174/1000
# 5/4 - 3s - loss: 0.1091 - val_loss: 0.3595
#
# Epoch 00175: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 175/1000
# 5/4 - 3s - loss: 0.1089 - val_loss: 0.3492
#
# Epoch 00176: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 176/1000
# 5/4 - 3s - loss: 0.1122 - val_loss: 0.3377
#
# Epoch 00177: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 177/1000
# 5/4 - 3s - loss: 0.1103 - val_loss: 0.3487
#
# Epoch 00178: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 178/1000
# 5/4 - 3s - loss: 0.1076 - val_loss: 0.3396
#
# Epoch 00179: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 179/1000
# 5/4 - 3s - loss: 0.1089 - val_loss: 1.0013
#
# Epoch 00180: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 180/1000
# 5/4 - 3s - loss: 0.1080 - val_loss: 0.4179
#
# Epoch 00181: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 181/1000
# 5/4 - 3s - loss: 0.1082 - val_loss: 0.4191
#
# Epoch 00182: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 182/1000
# 5/4 - 3s - loss: 0.1041 - val_loss: 0.4091
#
# Epoch 00183: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 183/1000
# 5/4 - 3s - loss: 0.1076 - val_loss: 0.4182
#
# Epoch 00184: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 184/1000
# 5/4 - 3s - loss: 0.1040 - val_loss: 0.3284
#
# Epoch 00185: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 185/1000
# 5/4 - 3s - loss: 0.1041 - val_loss: 0.3880
#
# Epoch 00186: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 186/1000
# 5/4 - 3s - loss: 0.1039 - val_loss: 0.3404
#
# Epoch 00187: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 187/1000
# 5/4 - 3s - loss: 0.1041 - val_loss: 0.3335
#
# Epoch 00188: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 188/1000
# 5/4 - 3s - loss: 0.1044 - val_loss: 0.3464
#
# Epoch 00189: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 189/1000
# 5/4 - 3s - loss: 0.1027 - val_loss: 0.3751
#
# Epoch 00190: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 190/1000
# 5/4 - 3s - loss: 0.1049 - val_loss: 0.3755
#
# Epoch 00191: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 191/1000
# 5/4 - 3s - loss: 0.1038 - val_loss: 0.4332
#
# Epoch 00192: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 192/1000
# 5/4 - 3s - loss: 0.1063 - val_loss: 0.3592
#
# Epoch 00193: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 193/1000
# 5/4 - 3s - loss: 0.1070 - val_loss: 0.3206
#
# Epoch 00194: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 194/1000
# 5/4 - 3s - loss: 0.1032 - val_loss: 0.3334
#
# Epoch 00195: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 195/1000
# 5/4 - 3s - loss: 0.1031 - val_loss: 0.3692
#
# Epoch 00196: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 196/1000
# 5/4 - 3s - loss: 0.1035 - val_loss: 0.3665
#
# Epoch 00197: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 197/1000
# 5/4 - 3s - loss: 0.1006 - val_loss: 0.3124
#
# Epoch 00198: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 198/1000
# 5/4 - 3s - loss: 0.1007 - val_loss: 0.3052
#
# Epoch 00199: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 199/1000
# 5/4 - 3s - loss: 0.1016 - val_loss: 0.3096
#
# Epoch 00200: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 200/1000
# Model saved in re_train_fp_--200--0.3986--0.0010000.
# 5/4 - 3s - loss: 0.1025 - val_loss: 0.3986
#
# Epoch 00201: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 201/1000
# 5/4 - 3s - loss: 0.1002 - val_loss: 0.4602
#
# Epoch 00202: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 202/1000
# 5/4 - 3s - loss: 0.1033 - val_loss: 0.4876
#
# Epoch 00203: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 203/1000
# 5/4 - 3s - loss: 0.1015 - val_loss: 0.3311
#
# Epoch 00204: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 204/1000
# 5/4 - 3s - loss: 0.1005 - val_loss: 0.3406
#
# Epoch 00205: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 205/1000
# 5/4 - 3s - loss: 0.1017 - val_loss: 0.2950
#
# Epoch 00206: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 206/1000
# 5/4 - 3s - loss: 0.1018 - val_loss: 0.3090
#
# Epoch 00207: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 207/1000
# 5/4 - 4s - loss: 0.0999 - val_loss: 0.3090
#
# Epoch 00208: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 208/1000
# 5/4 - 3s - loss: 0.1007 - val_loss: 0.3297
#
# Epoch 00209: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 209/1000
# 5/4 - 3s - loss: 0.1036 - val_loss: 0.4062
#
# Epoch 00210: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 210/1000
# 5/4 - 3s - loss: 0.1018 - val_loss: 0.3105
#
# Epoch 00211: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 211/1000
# 5/4 - 3s - loss: 0.0990 - val_loss: 0.2880
#
# Epoch 00212: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 212/1000
# 5/4 - 3s - loss: 0.1004 - val_loss: 0.3537
#
# Epoch 00213: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 213/1000
# 5/4 - 3s - loss: 0.0989 - val_loss: 0.4184
#
# Epoch 00214: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 214/1000
# 5/4 - 3s - loss: 0.1022 - val_loss: 0.3597
#
# Epoch 00215: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 215/1000
# 5/4 - 3s - loss: 0.0986 - val_loss: 0.4416
#
# Epoch 00216: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 216/1000
# 5/4 - 3s - loss: 0.0985 - val_loss: 0.4837
#
# Epoch 00217: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 217/1000
# 5/4 - 3s - loss: 0.0998 - val_loss: 0.3311
#
# Epoch 00218: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 218/1000
# 5/4 - 3s - loss: 0.0984 - val_loss: 0.2898
#
# Epoch 00219: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 219/1000
# 5/4 - 3s - loss: 0.0984 - val_loss: 0.3846
#
# Epoch 00220: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 220/1000
# 5/4 - 3s - loss: 0.1007 - val_loss: 0.3355
#
# Epoch 00221: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 221/1000
# 5/4 - 3s - loss: 0.0985 - val_loss: 0.2882
#
# Epoch 00222: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 222/1000
# 5/4 - 3s - loss: 0.1028 - val_loss: 0.3358
#
# Epoch 00223: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 223/1000
# 5/4 - 3s - loss: 0.1002 - val_loss: 0.2987
#
# Epoch 00224: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 224/1000
# 5/4 - 3s - loss: 0.0963 - val_loss: 0.3476
#
# Epoch 00225: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 225/1000
# 5/4 - 3s - loss: 0.0971 - val_loss: 0.3120
#
# Epoch 00226: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 226/1000
# 5/4 - 3s - loss: 0.1007 - val_loss: 0.3056
# Epoch 00227: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 227/1000
# 5/4 - 3s - loss: 0.0954 - val_loss: 0.3535
#
# Epoch 00228: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 228/1000
# 5/4 - 3s - loss: 0.0954 - val_loss: 0.3342
#
# Epoch 00229: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 229/1000
# 5/4 - 3s - loss: 0.0966 - val_loss: 0.2920
#
# Epoch 00230: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 230/1000
# 5/4 - 3s - loss: 0.0984 - val_loss: 0.2863
#
# Epoch 00231: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 231/1000
# 5/4 - 3s - loss: 0.0984 - val_loss: 0.2972
#
# Epoch 00232: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 232/1000
# 5/4 - 3s - loss: 0.0982 - val_loss: 0.3067
#
# Epoch 00233: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 233/1000
# 5/4 - 3s - loss: 0.0958 - val_loss: 0.3771
#
# Epoch 00234: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 234/1000
# 5/4 - 3s - loss: 0.0964 - val_loss: 0.3174
#
# Epoch 00235: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 235/1000
# 5/4 - 3s - loss: 0.0987 - val_loss: 0.2911
#
# Epoch 00236: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 236/1000
# 5/4 - 3s - loss: 0.0980 - val_loss: 0.3793
#
# Epoch 00237: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 237/1000
# 5/4 - 3s - loss: 0.0963 - val_loss: 0.2884
#
# Epoch 00238: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 238/1000
# 5/4 - 3s - loss: 0.0945 - val_loss: 0.3079
#
# Epoch 00239: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 239/1000
# 5/4 - 3s - loss: 0.0940 - val_loss: 0.2874
#
# Epoch 00240: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 240/1000
# 5/4 - 3s - loss: 0.0958 - val_loss: 0.8740
#
# Epoch 00241: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 241/1000
# 5/4 - 3s - loss: 0.0972 - val_loss: 0.2926
#
# Epoch 00242: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 242/1000
# 5/4 - 3s - loss: 0.0976 - val_loss: 0.2892
#
# Epoch 00243: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 243/1000
# 5/4 - 3s - loss: 0.0931 - val_loss: 0.2799
#
# Epoch 00244: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 244/1000
# 5/4 - 3s - loss: 0.0976 - val_loss: 0.3351
#
# Epoch 00245: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 245/1000
# 5/4 - 3s - loss: 0.0935 - val_loss: 0.2790
#
# Epoch 00246: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 246/1000
# 5/4 - 3s - loss: 0.0973 - val_loss: 0.2745
#
# Epoch 00247: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 247/1000
# 5/4 - 3s - loss: 0.0935 - val_loss: 0.3671
#
# Epoch 00248: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 248/1000
# 5/4 - 3s - loss: 0.0920 - val_loss: 0.3282
#
# Epoch 00249: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 249/1000
# 5/4 - 3s - loss: 0.0966 - val_loss: 0.2908
#
# Epoch 00250: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 250/1000
# Model saved in re_train_fp_--250--0.3601--0.0010000.
# 5/4 - 3s - loss: 0.0951 - val_loss: 0.3601
#
# Epoch 00251: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 251/1000
# 5/4 - 3s - loss: 0.0936 - val_loss: 0.3706
#
# Epoch 00252: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 252/1000
# 5/4 - 3s - loss: 0.0913 - val_loss: 0.3472
#
# Epoch 00253: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 253/1000
# 5/4 - 3s - loss: 0.0949 - val_loss: 0.3143
#
# Epoch 00254: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 254/1000
# 5/4 - 3s - loss: 0.0955 - val_loss: 0.2960
#
# Epoch 00255: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 255/1000
# 5/4 - 3s - loss: 0.0931 - val_loss: 0.3086
#
# Epoch 00256: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 256/1000
# 5/4 - 3s - loss: 0.0911 - val_loss: 0.2825
#
# Epoch 00257: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 257/1000
# 5/4 - 3s - loss: 0.0942 - val_loss: 0.3370
#
# Epoch 00258: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 258/1000
# 5/4 - 3s - loss: 0.0953 - val_loss: 0.3705
#
# Epoch 00259: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 259/1000
# 5/4 - 3s - loss: 0.0924 - val_loss: 0.3550
#
# Epoch 00260: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 260/1000
# 5/4 - 3s - loss: 0.0942 - val_loss: 0.3378
#
# Epoch 00261: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 261/1000
# 5/4 - 3s - loss: 0.0888 - val_loss: 0.3051
#
# Epoch 00262: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 262/1000
# 5/4 - 3s - loss: 0.0925 - val_loss: 0.3811
#
# Epoch 00263: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 263/1000
# 5/4 - 3s - loss: 0.0941 - val_loss: 0.3509
#
# Epoch 00264: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 264/1000
# 5/4 - 3s - loss: 0.0931 - val_loss: 0.3020
#
# Epoch 00265: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 265/1000
# 5/4 - 3s - loss: 0.0895 - val_loss: 0.3001
#
# Epoch 00266: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 266/1000
# 5/4 - 3s - loss: 0.0913 - val_loss: 0.3036
#
# Epoch 00267: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 267/1000
# 5/4 - 3s - loss: 0.0922 - val_loss: 0.3520
#
# Epoch 00268: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 268/1000
# 5/4 - 3s - loss: 0.0917 - val_loss: 0.2859
#
# Epoch 00269: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 269/1000
# 5/4 - 3s - loss: 0.0940 - val_loss: 0.2984
#
# Epoch 00270: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 270/1000
# 5/4 - 3s - loss: 0.0935 - val_loss: 0.2986
#
# Epoch 00271: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 271/1000
# 5/4 - 3s - loss: 0.0921 - val_loss: 0.2602
#
# Epoch 00272: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 272/1000
# 5/4 - 3s - loss: 0.0911 - val_loss: 0.4367
#
# Epoch 00273: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 273/1000
# 5/4 - 3s - loss: 0.0906 - val_loss: 0.3074
#
# Epoch 00274: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 274/1000
# 5/4 - 3s - loss: 0.0894 - val_loss: 0.3181
#
# Epoch 00275: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 275/1000
# 5/4 - 3s - loss: 0.0920 - val_loss: 0.2994
#
# Epoch 00276: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 276/1000
# 5/4 - 3s - loss: 0.0912 - val_loss: 0.3600
#
# Epoch 00277: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 277/1000
# 5/4 - 3s - loss: 0.0894 - val_loss: 0.3353
#
# Epoch 00278: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 278/1000
# 5/4 - 3s - loss: 0.0893 - val_loss: 0.2921
#
# Epoch 00279: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 279/1000
# 5/4 - 3s - loss: 0.0886 - val_loss: 0.3103
#
# Epoch 00280: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 280/1000
# 5/4 - 3s - loss: 0.0884 - val_loss: 0.3217
#
# Epoch 00281: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 281/1000
# 5/4 - 3s - loss: 0.0903 - val_loss: 0.2844
#
# Epoch 00282: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 282/1000
# 5/4 - 3s - loss: 0.0907 - val_loss: 0.3088
#
# Epoch 00283: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 283/1000
# 5/4 - 3s - loss: 0.0892 - val_loss: 0.2756
# Epoch 00284: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 284/1000
# 5/4 - 3s - loss: 0.0894 - val_loss: 0.3649
#
# Epoch 00285: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 285/1000
# 5/4 - 3s - loss: 0.0899 - val_loss: 0.3306
#
# Epoch 00286: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 286/1000
# 5/4 - 3s - loss: 0.0895 - val_loss: 0.2935
#
# Epoch 00287: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 287/1000
# 5/4 - 3s - loss: 0.0879 - val_loss: 0.3059
#
# Epoch 00288: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 288/1000
# 5/4 - 3s - loss: 0.0905 - val_loss: 0.3135
#
# Epoch 00289: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 289/1000
# 5/4 - 3s - loss: 0.0897 - val_loss: 0.3181
#
# Epoch 00290: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 290/1000
# 5/4 - 3s - loss: 0.0901 - val_loss: 0.2936
#
# Epoch 00291: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 291/1000
# 5/4 - 3s - loss: 0.0915 - val_loss: 0.3395
#
# Epoch 00292: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 292/1000
# 5/4 - 3s - loss: 0.0890 - val_loss: 0.3379
#
# Epoch 00293: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 293/1000
# 5/4 - 3s - loss: 0.0904 - val_loss: 0.3438
#
# Epoch 00294: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 294/1000
# 5/4 - 3s - loss: 0.0873 - val_loss: 0.2721
#
# Epoch 00295: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 295/1000
# 5/4 - 3s - loss: 0.0897 - val_loss: 0.3195
#
# Epoch 00296: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 296/1000
# 5/4 - 3s - loss: 0.0925 - val_loss: 0.3332
#
# Epoch 00297: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 297/1000
# 5/4 - 3s - loss: 0.0888 - val_loss: 0.3215
#
# Epoch 00298: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 298/1000
# 5/4 - 3s - loss: 0.0873 - val_loss: 0.2880
#
# Epoch 00299: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 299/1000
# 5/4 - 3s - loss: 0.0895 - val_loss: 0.2775
#
# Epoch 00300: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 300/1000
# Model saved in re_train_fp_--300--0.3424--0.0010000.
# 5/4 - 3s - loss: 0.0854 - val_loss: 0.3424
#
# Epoch 00301: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 301/1000
# 5/4 - 3s - loss: 0.0863 - val_loss: 0.3114
#
# Epoch 00302: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 302/1000
# 5/4 - 3s - loss: 0.0909 - val_loss: 0.3164
#
# Epoch 00303: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 303/1000
# 5/4 - 3s - loss: 0.0885 - val_loss: 0.3082
#
# Epoch 00304: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 304/1000
# 5/4 - 3s - loss: 0.0883 - val_loss: 0.2793
#
# Epoch 00305: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 305/1000
# 5/4 - 3s - loss: 0.0891 - val_loss: 0.3325
#
# Epoch 00306: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 306/1000
# 5/4 - 3s - loss: 0.0831 - val_loss: 0.3482
#
# Epoch 00307: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 307/1000
# 5/4 - 3s - loss: 0.0856 - val_loss: 0.2630
#
# Epoch 00308: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 308/1000
# 5/4 - 3s - loss: 0.0853 - val_loss: 0.2864
#
# Epoch 00309: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 309/1000
# 5/4 - 3s - loss: 0.0867 - val_loss: 0.2871
#
# Epoch 00310: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 310/1000
# 5/4 - 3s - loss: 0.0867 - val_loss: 0.2844
#
# Epoch 00311: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 311/1000
# 5/4 - 3s - loss: 0.0872 - val_loss: 0.2703
#
# Epoch 00312: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 312/1000
# 5/4 - 3s - loss: 0.0871 - val_loss: 0.2883
#
# Epoch 00313: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 313/1000
# 5/4 - 3s - loss: 0.0843 - val_loss: 0.2891
#
# Epoch 00314: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 314/1000
# 5/4 - 3s - loss: 0.0868 - val_loss: 0.4169
#
# Epoch 00315: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 315/1000
# 5/4 - 3s - loss: 0.0921 - val_loss: 0.3996
#
# Epoch 00316: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 316/1000
# 5/4 - 3s - loss: 0.0895 - val_loss: 0.3098
#
# Epoch 00317: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 317/1000
# 5/4 - 3s - loss: 0.0898 - val_loss: 0.3466
#
# Epoch 00318: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 318/1000
# 5/4 - 3s - loss: 0.0897 - val_loss: 0.2677
#
# Epoch 00319: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 319/1000
# 5/4 - 3s - loss: 0.0843 - val_loss: 0.3361
#
# Epoch 00320: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 320/1000
# 5/4 - 4s - loss: 0.0867 - val_loss: 0.3163
#
# Epoch 00321: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 321/1000
# 5/4 - 3s - loss: 0.0874 - val_loss: 0.3021
#
# Epoch 00322: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 322/1000
# 5/4 - 3s - loss: 0.0849 - val_loss: 0.2941
#
# Epoch 00323: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 323/1000
# 5/4 - 3s - loss: 0.0858 - val_loss: 0.3754
#
# Epoch 00324: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 324/1000
# 5/4 - 3s - loss: 0.0842 - val_loss: 0.4274
#
# Epoch 00325: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 325/1000
# 5/4 - 3s - loss: 0.0843 - val_loss: 0.3506
#
# Epoch 00326: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 326/1000
# 5/4 - 3s - loss: 0.0823 - val_loss: 0.3699
#
# Epoch 00327: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 327/1000
# 5/4 - 3s - loss: 0.0825 - val_loss: 0.4110
#
# Epoch 00328: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 328/1000
# 5/4 - 3s - loss: 0.0868 - val_loss: 0.2653
#
# Epoch 00329: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 329/1000
# 5/4 - 3s - loss: 0.0869 - val_loss: 0.3206
#
# Epoch 00330: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 330/1000
# 5/4 - 3s - loss: 0.0850 - val_loss: 0.3121
#
# Epoch 00331: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 331/1000
# 5/4 - 3s - loss: 0.0884 - val_loss: 0.3109
#
# ...
#
# Epoch 00891: LearningRateScheduler reducing learning rate to 4.521792417370704e-06.
# Epoch 891/1000
# 5/4 - 3s - loss: 0.0638 - val_loss: 0.1716
#
# Epoch 00892: LearningRateScheduler reducing learning rate to 4.4596276268190975e-06.
# Epoch 892/1000
# 5/4 - 3s - loss: 0.0628 - val_loss: 0.1729
#
# Epoch 00893: LearningRateScheduler reducing learning rate to 4.398317466650227e-06.
# Epoch 893/1000
# 5/4 - 3s - loss: 0.0628 - val_loss: 0.1733
#
# Epoch 00894: LearningRateScheduler reducing learning rate to 4.337850187558992e-06.
# Epoch 894/1000
# 5/4 - 3s - loss: 0.0593 - val_loss: 0.1702
#
# Epoch 00895: LearningRateScheduler reducing learning rate to 4.2782142017676195e-06.
# Epoch 895/1000
# 5/4 - 3s - loss: 0.0614 - val_loss: 0.1712
#
# Epoch 00896: LearningRateScheduler reducing learning rate to 4.2193980808050316e-06.
# Epoch 896/1000
# 5/4 - 3s - loss: 0.0619 - val_loss: 0.1689
#
# Epoch 00897: LearningRateScheduler reducing learning rate to 4.16139055331671e-06.
# Epoch 897/1000
# 5/4 - 3s - loss: 0.0627 - val_loss: 0.1731
#
# Epoch 00898: LearningRateScheduler reducing learning rate to 4.104180502904713e-06.
# Epoch 898/1000
# 5/4 - 3s - loss: 0.0605 - val_loss: 0.1728
#
# Epoch 00899: LearningRateScheduler reducing learning rate to 4.047756965997326e-06.
# Epoch 899/1000
# 5/4 - 3s - loss: 0.0594 - val_loss: 0.1717
#
# Epoch 00900: LearningRateScheduler reducing learning rate to 3.992109129748054e-06.
# Epoch 900/1000
# Model saved in re_train_fp_--900--0.1707--0.0000040.
# 5/4 - 3s - loss: 0.0621 - val_loss: 0.1707
#
# Epoch 00901: LearningRateScheduler reducing learning rate to 3.937226329963483e-06.
# Epoch 901/1000
# 5/4 - 3s - loss: 0.0621 - val_loss: 0.1742
#
# Epoch 00902: LearningRateScheduler reducing learning rate to 3.883098049059609e-06.
# Epoch 902/1000
# 5/4 - 3s - loss: 0.0618 - val_loss: 0.1716
#
# Epoch 00903: LearningRateScheduler reducing learning rate to 3.8297139140462855e-06.
# Epoch 903/1000
# 5/4 - 3s - loss: 0.0637 - val_loss: 0.1736
#
# Epoch 00904: LearningRateScheduler reducing learning rate to 3.777063694539369e-06.
# Epoch 904/1000
# 5/4 - 3s - loss: 0.0606 - val_loss: 0.1733
#
# Epoch 00905: LearningRateScheduler reducing learning rate to 3.725137300800214e-06.
# Epoch 905/1000
# 5/4 - 3s - loss: 0.0603 - val_loss: 0.1716
#
# Epoch 00906: LearningRateScheduler reducing learning rate to 3.673924781802079e-06.
# Epoch 906/1000
# 5/4 - 3s - loss: 0.0625 - val_loss: 0.1718
#
# Epoch 00907: LearningRateScheduler reducing learning rate to 3.6234163233231515e-06.
# Epoch 907/1000
# 5/4 - 3s - loss: 0.0628 - val_loss: 0.1735
#
# Epoch 00908: LearningRateScheduler reducing learning rate to 3.5736022460657898e-06.
# Epoch 908/1000
# 5/4 - 3s - loss: 0.0624 - val_loss: 0.1705
#
# Epoch 00909: LearningRateScheduler reducing learning rate to 3.524473003801589e-06.
# Epoch 909/1000
# 5/4 - 3s - loss: 0.0619 - val_loss: 0.1701
#
# Epoch 00910: LearningRateScheduler reducing learning rate to 3.4760191815419824e-06.
# Epoch 910/1000
# 5/4 - 3s - loss: 0.0619 - val_loss: 0.1727
#
# Epoch 00911: LearningRateScheduler reducing learning rate to 3.4282314937339725e-06.
# Epoch 911/1000
# 5/4 - 3s - loss: 0.0605 - val_loss: 0.1760
#
# Epoch 00912: LearningRateScheduler reducing learning rate to 3.381100782480687e-06.
# Epoch 912/1000
# 5/4 - 3s - loss: 0.0606 - val_loss: 0.1712
#
# Epoch 00913: LearningRateScheduler reducing learning rate to 3.334618015786368e-06.
# Epoch 913/1000
# 5/4 - 3s - loss: 0.0603 - val_loss: 0.1710
#
# Epoch 00914: LearningRateScheduler reducing learning rate to 3.2887742858255128e-06.
# Epoch 914/1000
# 5/4 - 3s - loss: 0.0620 - val_loss: 0.1706
#
# Epoch 00915: LearningRateScheduler reducing learning rate to 3.243560807235814e-06.
# Epoch 915/1000
# 5/4 - 3s - loss: 0.0600 - val_loss: 0.1710
#
# Epoch 00916: LearningRateScheduler reducing learning rate to 3.1989689154345404e-06.
# Epoch 916/1000
# 5/4 - 3s - loss: 0.0607 - val_loss: 0.1722
#
# Epoch 00917: LearningRateScheduler reducing learning rate to 3.154990064958091e-06.
# Epoch 917/1000
# 5/4 - 3s - loss: 0.0634 - val_loss: 0.1729
#
# Epoch 00918: LearningRateScheduler reducing learning rate to 3.111615827824363e-06.
# Epoch 918/1000
# 5/4 - 3s - loss: 0.0633 - val_loss: 0.1735
#
# Epoch 00919: LearningRateScheduler reducing learning rate to 3.0688378919176455e-06.
# Epoch 919/1000
# 5/4 - 3s - loss: 0.0635 - val_loss: 0.1717
#
# Epoch 00920: LearningRateScheduler reducing learning rate to 3.0266480593956947e-06.
# Epoch 920/1000
# 5/4 - 3s - loss: 0.0612 - val_loss: 0.1719
#
# Epoch 00921: LearningRateScheduler reducing learning rate to 2.9850382451187328e-06.
# Epoch 921/1000
# 5/4 - 3s - loss: 0.0603 - val_loss: 0.1727
#
# Epoch 00922: LearningRateScheduler reducing learning rate to 2.944000475100037e-06.
# Epoch 922/1000
# 5/4 - 3s - loss: 0.0619 - val_loss: 0.1758
#
# Epoch 00923: LearningRateScheduler reducing learning rate to 2.9035268849778173e-06.
# Epoch 923/1000
# 5/4 - 3s - loss: 0.0635 - val_loss: 0.1724
#
# Epoch 00924: LearningRateScheduler reducing learning rate to 2.863609718508119e-06.
# Epoch 924/1000
# 5/4 - 3s - loss: 0.0633 - val_loss: 0.1714
#
# Epoch 00925: LearningRateScheduler reducing learning rate to 2.8242413260784363e-06.
# Epoch 925/1000
# 5/4 - 3s - loss: 0.0592 - val_loss: 0.1743
#
# Epoch 00926: LearningRateScheduler reducing learning rate to 2.7854141632417697e-06.
# Epoch 926/1000
# 5/4 - 3s - loss: 0.0595 - val_loss: 0.1693
#
# Epoch 00927: LearningRateScheduler reducing learning rate to 2.747120789270815e-06.
# Epoch 927/1000
# 5/4 - 3s - loss: 0.0608 - val_loss: 0.1703
#
# Epoch 00928: LearningRateScheduler reducing learning rate to 2.709353865732053e-06.
# Epoch 928/1000
# 5/4 - 3s - loss: 0.0614 - val_loss: 0.1689
#
# Epoch 00929: LearningRateScheduler reducing learning rate to 2.6721061550794362e-06.
# Epoch 929/1000
# 5/4 - 3s - loss: 0.0626 - val_loss: 0.1746
#
# Epoch 00930: LearningRateScheduler reducing learning rate to 2.635370519267397e-06.
# Epoch 930/1000
# 5/4 - 3s - loss: 0.0615 - val_loss: 0.1699
#
# Epoch 00931: LearningRateScheduler reducing learning rate to 2.599139918382937e-06.
# Epoch 931/1000
# 5/4 - 3s - loss: 0.0599 - val_loss: 0.1693
#
# Epoch 00932: LearningRateScheduler reducing learning rate to 2.5634074092965166e-06.
# Epoch 932/1000
# 5/4 - 3s - loss: 0.0640 - val_loss: 0.1731
#
# Epoch 00933: LearningRateScheduler reducing learning rate to 2.5281661443315022e-06.
# Epoch 933/1000
# 5/4 - 3s - loss: 0.0607 - val_loss: 0.1732
#
# Epoch 00934: LearningRateScheduler reducing learning rate to 2.4934093699518818e-06.
# Epoch 934/1000
# 5/4 - 3s - loss: 0.0626 - val_loss: 0.1742
#
# Epoch 00935: LearningRateScheduler reducing learning rate to 2.459130425468046e-06.
# Epoch 935/1000
# 5/4 - 3s - loss: 0.0594 - val_loss: 0.1737
#
# Epoch 00936: LearningRateScheduler reducing learning rate to 2.4253227417603553e-06.
# Epoch 936/1000
# 5/4 - 3s - loss: 0.0615 - val_loss: 0.1722
#
# Epoch 00937: LearningRateScheduler reducing learning rate to 2.3919798400202414e-06.
# Epoch 937/1000
# 5/4 - 3s - loss: 0.0623 - val_loss: 0.1735
#
# Epoch 00938: LearningRateScheduler reducing learning rate to 2.359095330508638e-06.
# Epoch 938/1000
# 5/4 - 3s - loss: 0.0623 - val_loss: 0.1703
#
# Epoch 00939: LearningRateScheduler reducing learning rate to 2.32666291133146e-06.
# Epoch 939/1000
# 5/4 - 3s - loss: 0.0598 - val_loss: 0.1742
#
# Epoch 00940: LearningRateScheduler reducing learning rate to 2.294676367231938e-06.
# Epoch 940/1000
# 5/4 - 3s - loss: 0.0631 - val_loss: 0.1714
#
# Epoch 00941: LearningRateScheduler reducing learning rate to 2.263129568399532e-06.
# Epoch 941/1000
# 5/4 - 3s - loss: 0.0593 - val_loss: 0.1748
#
# Epoch 00942: LearningRateScheduler reducing learning rate to 2.232016469295235e-06.
# Epoch 942/1000
# 5/4 - 3s - loss: 0.0608 - val_loss: 0.1731
#
# Epoch 00943: LearningRateScheduler reducing learning rate to 2.2013311074930328e-06.
# Epoch 943/1000
# 5/4 - 3s - loss: 0.0631 - val_loss: 0.1749
#
# Epoch 00944: LearningRateScheduler reducing learning rate to 2.1710676025372678e-06.
# Epoch 944/1000
# 5/4 - 3s - loss: 0.0617 - val_loss: 0.1726
#
# Epoch 00945: LearningRateScheduler reducing learning rate to 2.141220154815732e-06.
# Epoch 945/1000
# 5/4 - 3s - loss: 0.0618 - val_loss: 0.1727
#
# Epoch 00946: LearningRateScheduler reducing learning rate to 2.111783044448245e-06.
# Epoch 946/1000
# 5/4 - 3s - loss: 0.0612 - val_loss: 0.1736
#
# Epoch 00947: LearningRateScheduler reducing learning rate to 2.0827506301905172e-06.
# Epoch 947/1000
# 5/4 - 3s - loss: 0.0621 - val_loss: 0.1702
#
# Epoch 00948: LearningRateScheduler reducing learning rate to 2.0541173483530672e-06.
# Epoch 948/1000
# 5/4 - 3s - loss: 0.0612 - val_loss: 0.1693
#
# Epoch 00949: LearningRateScheduler reducing learning rate to 2.0258777117350184e-06.
# Epoch 949/1000
# 5/4 - 3s - loss: 0.0614 - val_loss: 0.1737
#
# Epoch 00950: LearningRateScheduler reducing learning rate to 1.998026308572552e-06.
# Epoch 950/1000
# Model saved in re_train_fp_--950--0.1727--0.0000020.
# 5/4 - 3s - loss: 0.0619 - val_loss: 0.1727
#
# Epoch 00951: LearningRateScheduler reducing learning rate to 1.9705578015018017e-06.
# Epoch 951/1000
# 5/4 - 3s - loss: 0.0595 - val_loss: 0.1713
#
# Epoch 00952: LearningRateScheduler reducing learning rate to 1.9434669265360234e-06.
# Epoch 952/1000
# 5/4 - 3s - loss: 0.0601 - val_loss: 0.1728
#
# Epoch 00953: LearningRateScheduler reducing learning rate to 1.9167484920568164e-06.
# Epoch 953/1000
# 5/4 - 3s - loss: 0.0614 - val_loss: 0.1713
#
# Epoch 00954: LearningRateScheduler reducing learning rate to 1.8903973778192228e-06.
# Epoch 954/1000
# 5/4 - 3s - loss: 0.0629 - val_loss: 0.1731
#
# Epoch 00955: LearningRateScheduler reducing learning rate to 1.8644085339704887e-06.
# Epoch 955/1000
# 5/4 - 3s - loss: 0.0612 - val_loss: 0.1739
#
# Epoch 00956: LearningRateScheduler reducing learning rate to 1.8387769800823286e-06.
# Epoch 956/1000
# 5/4 - 3s - loss: 0.0610 - val_loss: 0.1711
#
# Epoch 00957: LearningRateScheduler reducing learning rate to 1.813497804196497e-06.
# Epoch 957/1000
# 5/4 - 3s - loss: 0.0627 - val_loss: 0.1713
#
# Epoch 00958: LearningRateScheduler reducing learning rate to 1.7885661618834635e-06.
# Epoch 958/1000
# 5/4 - 3s - loss: 0.0626 - val_loss: 0.1712
#
# Epoch 00959: LearningRateScheduler reducing learning rate to 1.7639772753140468e-06.
# Epoch 959/1000
# 5/4 - 3s - loss: 0.0613 - val_loss: 0.1712
#
# Epoch 00960: LearningRateScheduler reducing learning rate to 1.7397264323438028e-06.
# Epoch 960/1000
# 5/4 - 3s - loss: 0.0622 - val_loss: 0.1724
#
# Epoch 00961: LearningRateScheduler reducing learning rate to 1.7158089856100067e-06.
# Epoch 961/1000
# 5/4 - 3s - loss: 0.0620 - val_loss: 0.1721
#
# Epoch 00962: LearningRateScheduler reducing learning rate to 1.692220351641039e-06.
# Epoch 962/1000
# 5/4 - 3s - loss: 0.0614 - val_loss: 0.1721
#
# Epoch 00963: LearningRateScheduler reducing learning rate to 1.6689560099780253e-06.
# Epoch 963/1000
# 5/4 - 3s - loss: 0.0618 - val_loss: 0.1720
#
# Epoch 00964: LearningRateScheduler reducing learning rate to 1.6460115023085519e-06.
# Epoch 964/1000
# 5/4 - 3s - loss: 0.0613 - val_loss: 0.1723
#
# Epoch 00965: LearningRateScheduler reducing learning rate to 1.6233824316122802e-06.
# Epoch 965/1000
# 5/4 - 3s - loss: 0.0610 - val_loss: 0.1719
#
# Epoch 00966: LearningRateScheduler reducing learning rate to 1.6010644613183185e-06.
# Epoch 966/1000
# 5/4 - 3s - loss: 0.0620 - val_loss: 0.1730
#
# Epoch 00967: LearningRateScheduler reducing learning rate to 1.5790533144741766e-06.
# Epoch 967/1000
# 5/4 - 3s - loss: 0.0632 - val_loss: 0.1739
#
# Epoch 00968: LearningRateScheduler reducing learning rate to 1.557344772926136e-06.
# Epoch 968/1000
# 5/4 - 3s - loss: 0.0586 - val_loss: 0.1726
#
# Epoch 00969: LearningRateScheduler reducing learning rate to 1.5359346765108993e-06.
# Epoch 969/1000
# 5/4 - 3s - loss: 0.0620 - val_loss: 0.1732
#
# Epoch 00970: LearningRateScheduler reducing learning rate to 1.5148189222583469e-06.
# Epoch 970/1000
# 5/4 - 3s - loss: 0.0591 - val_loss: 0.1718
#
# Epoch 00971: LearningRateScheduler reducing learning rate to 1.4939934636052587e-06.
# Epoch 971/1000
# 5/4 - 3s - loss: 0.0627 - val_loss: 0.1708
#
# Epoch 00972: LearningRateScheduler reducing learning rate to 1.4734543096198368e-06.
# Epoch 972/1000
# 5/4 - 3s - loss: 0.0618 - val_loss: 0.1715
#
# Epoch 00973: LearningRateScheduler reducing learning rate to 1.4531975242368965e-06.
# Epoch 973/1000
# 5/4 - 3s - loss: 0.0623 - val_loss: 0.1723
#
# Epoch 00974: LearningRateScheduler reducing learning rate to 1.4332192255035751e-06.
# Epoch 974/1000
# 5/4 - 3s - loss: 0.0610 - val_loss: 0.1699
#
# Epoch 00975: LearningRateScheduler reducing learning rate to 1.413515584835397e-06.
# Epoch 975/1000
# 5/4 - 3s - loss: 0.0605 - val_loss: 0.1719
#
# Epoch 00976: LearningRateScheduler reducing learning rate to 1.3940828262825798e-06.
# Epoch 976/1000
# 5/4 - 3s - loss: 0.0631 - val_loss: 0.1728
#
# Epoch 00977: LearningRateScheduler reducing learning rate to 1.3749172258064205e-06.
# Epoch 977/1000
# 5/4 - 3s - loss: 0.0611 - val_loss: 0.1713
#
# Epoch 00978: LearningRateScheduler reducing learning rate to 1.3560151105656346e-06.
# Epoch 978/1000
# 5/4 - 4s - loss: 0.0627 - val_loss: 0.1725
#
# Epoch 00979: LearningRateScheduler reducing learning rate to 1.3373728582124978e-06.
# Epoch 979/1000
# 5/4 - 3s - loss: 0.0608 - val_loss: 0.1727
#
# Epoch 00980: LearningRateScheduler reducing learning rate to 1.3189868961986706e-06.
# Epoch 980/1000
# 5/4 - 3s - loss: 0.0617 - val_loss: 0.1727
#
# Epoch 00981: LearningRateScheduler reducing learning rate to 1.3008537010905722e-06.
# Epoch 981/1000
# 5/4 - 3s - loss: 0.0609 - val_loss: 0.1729
#
# Epoch 00982: LearningRateScheduler reducing learning rate to 1.2829697978941492e-06.
# Epoch 982/1000
# 5/4 - 3s - loss: 0.0631 - val_loss: 0.1715
#
# Epoch 00983: LearningRateScheduler reducing learning rate to 1.2653317593889445e-06.
# Epoch 983/1000
# 5/4 - 3s - loss: 0.0615 - val_loss: 0.1727
#
# Epoch 00984: LearningRateScheduler reducing learning rate to 1.2479362054713119e-06.
# Epoch 984/1000
# 5/4 - 3s - loss: 0.0633 - val_loss: 0.1727
#
# Epoch 00985: LearningRateScheduler reducing learning rate to 1.2307798025066665e-06.
# Epoch 985/1000
# 5/4 - 3s - loss: 0.0605 - val_loss: 0.1727
#
# Epoch 00986: LearningRateScheduler reducing learning rate to 1.2138592626906293e-06.
# Epoch 986/1000
# 5/4 - 3s - loss: 0.0605 - val_loss: 0.1717
#
# Epoch 00987: LearningRateScheduler reducing learning rate to 1.1971713434189676e-06.
# Epoch 987/1000
# 5/4 - 3s - loss: 0.0607 - val_loss: 0.1731
#
# Epoch 00988: LearningRateScheduler reducing learning rate to 1.180712846666191e-06.
# Epoch 988/1000
# 5/4 - 3s - loss: 0.0612 - val_loss: 0.1736
#
# Epoch 00989: LearningRateScheduler reducing learning rate to 1.1644806183726873e-06.
# Epoch 989/1000
# 5/4 - 3s - loss: 0.0605 - val_loss: 0.1724
#
# Epoch 00990: LearningRateScheduler reducing learning rate to 1.148471547840291e-06.
# Epoch 990/1000
# 5/4 - 3s - loss: 0.0626 - val_loss: 0.1723
#
# Epoch 00991: LearningRateScheduler reducing learning rate to 1.1326825671361546e-06.
# Epoch 991/1000
# 5/4 - 3s - loss: 0.0618 - val_loss: 0.1704
#
# Epoch 00992: LearningRateScheduler reducing learning rate to 1.117110650504825e-06.
# Epoch 992/1000
# 5/4 - 3s - loss: 0.0623 - val_loss: 0.1747
#
# Epoch 00993: LearningRateScheduler reducing learning rate to 1.1017528137883882e-06.
# Epoch 993/1000
# 5/4 - 3s - loss: 0.0603 - val_loss: 0.1713
#
# Epoch 00994: LearningRateScheduler reducing learning rate to 1.0866061138545977e-06.
# Epoch 994/1000
# 5/4 - 3s - loss: 0.0597 - val_loss: 0.1741
#
# Epoch 00995: LearningRateScheduler reducing learning rate to 1.0716676480328642e-06.
# Epoch 995/1000
# 5/4 - 3s - loss: 0.0651 - val_loss: 0.1724
#
# Epoch 00996: LearningRateScheduler reducing learning rate to 1.0569345535579894e-06.
# Epoch 996/1000
# 5/4 - 3s - loss: 0.0610 - val_loss: 0.1671
#
# Epoch 00997: LearningRateScheduler reducing learning rate to 1.0424040070215578e-06.
# Epoch 997/1000
# 5/4 - 3s - loss: 0.0604 - val_loss: 0.1698
#
# Epoch 00998: LearningRateScheduler reducing learning rate to 1.0280732238308657e-06.
# Epoch 998/1000
# 5/4 - 3s - loss: 0.0612 - val_loss: 0.1717
#
# Epoch 00999: LearningRateScheduler reducing learning rate to 1.0139394576752928e-06.
# Epoch 999/1000
# 5/4 - 3s - loss: 0.0610 - val_loss: 0.1718
#
# Epoch 01000: LearningRateScheduler reducing learning rate to 1.0000000000000012e-06.
# Epoch 1000/1000
# Model saved in re_train_fp_--1000--0.1725--0.0000010.
# 5/4 - 3s - loss: 0.0598 - val_loss: 0.1725
